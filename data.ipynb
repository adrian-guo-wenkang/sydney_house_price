# %%
from datetime import datetime, date
import warnings
import numpy as np
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
pd.options.display.max_columns = None
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Combine and clean data files from the NSW government
#
# The following code joins all of the CSV files from NSW government into a single CSV.

# %%
# All data files from the NSW government can be found at http://maps.six.nsw.gov.au/csv/current/suburb/
# All of the 4325 files are quite large and should be updated, so they are not included in the github repo.

# If a new gov dataset is needed, just re-download all the csv files from the website above and run this cell.
# I used chrono download manager's sniffer feature to download them all.

# I know the analysis is based on Sydney house prices but these government data files are for the whole state of NSW Australia.
# I'm sure there's a smart way to get rid of some of these files to reduce the data size, and improve process time,
# but for now I'm just too lazy to do that.

# uncomment the following code if you want to re-combine the csv files.

# extension = 'csv'
# all_filenames = [i for i in glob.glob('./data/gov/*.{}'.format(extension))]

# #combine all files in the list
# combined = pd.concat([pd.read_csv(f) for f in all_filenames ])

# # removing less useful columns
# combined = combined.drop(['MULTI-PROPERTY SALE (Y/N)', 'STRATA/NON STRATA', 'PROPERTY NUMBER',
#                'DEALING NUMBER', 'EXTRACTION DATE'], axis=1)

# # removing duplicates

# combined = combined.drop_duplicates(keep='last')

# # do the hard work now so don't have to do this again each time
# combined['SALE DATE']=pd.to_datetime(combined['SALE DATE'])

# combined.shape

# #export to csv
# combined.to_csv( "./data/gov_combined.csv", index=False, encoding='utf-8-sig')

# %%
# check the shape and columns of the data frame
gov1 = pd.read_csv('./data/gov_combined.csv') # if you don't want to run the prvious cell again every time, just comment it out
print(gov1.shape)
gov1.head()
# Out:
# (908210, 4)
#                                           ADDRESS  SALE PRICE   SALE DATE  \
# 0  7685 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      435000  2019-08-30
# 1     2162 AARONS PASS ROAD, AARONS PASS NSW 2850      315000  2017-08-22
# 2  7749 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      340000  2019-12-05
# 3          159 SUTTERS LANE, AARONS PASS NSW 2850      365000  2021-01-20
# 4  8248 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      700000  2018-10-19
#
#        AREA
# 0  400100.0
# 1  428500.0
# 2  398500.0
# 3  470800.0
# 4  402000.0

# %%
# Split street address and suburb

addr = gov1.ADDRESS.str.split(
    ',', n=1, expand=True).apply(lambda x: x.str.strip())
gov2 = gov1.copy()
for i in addr.columns:
    gov2[i] = addr[i]

# %%
gov2.head()
# Out:
#                                           ADDRESS  SALE PRICE   SALE DATE  \
# 0  7685 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      435000  2019-08-30
# 1     2162 AARONS PASS ROAD, AARONS PASS NSW 2850      315000  2017-08-22
# 2  7749 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      340000  2019-12-05
# 3          159 SUTTERS LANE, AARONS PASS NSW 2850      365000  2021-01-20
# 4  8248 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850      700000  2018-10-19
#
#        AREA                         0                     1
# 0  400100.0  7685 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850
# 1  428500.0     2162 AARONS PASS ROAD  AARONS PASS NSW 2850
# 2  398500.0  7749 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850
# 3  470800.0          159 SUTTERS LANE  AARONS PASS NSW 2850
# 4  402000.0  8248 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850

# %%
gov2.rename(columns={0:'ADDR', 1:'SUBURB', 'SALE DATE':'DATE','SALE PRICE':'PRICE'},inplace=True)
gov2.head()
# Out:
#                                           ADDRESS   PRICE        DATE  \
# 0  7685 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850  435000  2019-08-30
# 1     2162 AARONS PASS ROAD, AARONS PASS NSW 2850  315000  2017-08-22
# 2  7749 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850  340000  2019-12-05
# 3          159 SUTTERS LANE, AARONS PASS NSW 2850  365000  2021-01-20
# 4  8248 CASTLEREAGH HIGHWAY, AARONS PASS NSW 2850  700000  2018-10-19
#
#        AREA                      ADDR                SUBURB
# 0  400100.0  7685 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850
# 1  428500.0     2162 AARONS PASS ROAD  AARONS PASS NSW 2850
# 2  398500.0  7749 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850
# 3  470800.0          159 SUTTERS LANE  AARONS PASS NSW 2850
# 4  402000.0  8248 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850

# %%
# Leaving only the useful columns

cols = ['ADDR','SUBURB','PRICE','AREA','DATE']
gov3 = gov2[cols]
gov3.columns = ['Address','Suburb','Price','Size','Date']
gov3.head()
# Out:
#                     Address                Suburb   Price      Size  \
# 0  7685 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850  435000  400100.0
# 1     2162 AARONS PASS ROAD  AARONS PASS NSW 2850  315000  428500.0
# 2  7749 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850  340000  398500.0
# 3          159 SUTTERS LANE  AARONS PASS NSW 2850  365000  470800.0
# 4  8248 CASTLEREAGH HIGHWAY  AARONS PASS NSW 2850  700000  402000.0
#
#          Date
# 0  2019-08-30
# 1  2017-08-22
# 2  2019-12-05
# 3  2021-01-20
# 4  2018-10-19

# %%
sales_gov = gov3.copy()

# %% [markdown]
# ## Combine and clean data scraped from RateMyAgent.com.au

# %%
# All data files from the RateMyAgent website are scraped with some tool I shall not name.
# The data should be updated once every month.
# uncomment the following code if you want to re-combine the csv files.

# extension = 'csv'
# all_filenames = [i for i in glob.glob('./data/rma/*.{}'.format(extension))]

# #combine all files in the list
# combined = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined.to_csv( "./data/rma_combined.csv", index=False, encoding='utf-8-sig')

# %%
rma = pd.read_csv('./data/rma_combined.csv')
rma.shape
# Out:
# (28405, 9)

# %%
rma.head()
# Out:
#                                                 Link              Address  \
# 0  https://www.ratemyagent.com.au/real-estate-age...  7A Australia Street
# 1  https://www.ratemyagent.com.au/real-estate-age...      9/46 Stewart St
# 2  https://www.ratemyagent.com.au/real-estate-age...    39 William Street
# 3  https://www.ratemyagent.com.au/real-estate-age...    7/12 Union Street
# 4  https://www.ratemyagent.com.au/real-estate-age...  404/2A Cooks Avenue
#
#                 Suburb  Beds  Baths  Carpark       Type  \
# 0  Camperdown NSW 2050   2.0    2.0      1.0  Townhouse
# 1   Ermington NSW 2115   3.0    2.0      1.0  Townhouse
# 2   Granville NSW 2142   1.0    1.0      1.0       Unit
# 3   West Ryde NSW 2114   2.0    1.0      1.0       Unit
# 4  Canterbury NSW 2193   2.0    2.0      2.0       Unit
#
#                               Sale Type              Price
# 0       Sold by Auction  on 02 Nov 2021         $1,950,000
# 1  Sold by Private Sale  on 01 Nov 2021           $960,000
# 2  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 3  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 4  Sold by Private Sale  on 01 Nov 2021           $740,000

# %%
# remove duplicates

rma1 = rma.drop_duplicates(keep='last')
rma1.shape
# Out:
# (28353, 9)

# %%
rma1.isnull().sum()
# Out:
# Link           74
# Address         1
# Suburb          1
# Beds           38
# Baths          71
# Carpark      2159
# Type          220
# Sale Type       9
# Price           1
# dtype: int64

# %%
# Dropping rows that are missing important values

rma1.dropna(subset=['Price','Beds'],inplace=True)
rma1.head()
# Out:
#                                                 Link              Address  \
# 0  https://www.ratemyagent.com.au/real-estate-age...  7A Australia Street
# 1  https://www.ratemyagent.com.au/real-estate-age...      9/46 Stewart St
# 2  https://www.ratemyagent.com.au/real-estate-age...    39 William Street
# 3  https://www.ratemyagent.com.au/real-estate-age...    7/12 Union Street
# 4  https://www.ratemyagent.com.au/real-estate-age...  404/2A Cooks Avenue
#
#                 Suburb  Beds  Baths  Carpark       Type  \
# 0  Camperdown NSW 2050   2.0    2.0      1.0  Townhouse
# 1   Ermington NSW 2115   3.0    2.0      1.0  Townhouse
# 2   Granville NSW 2142   1.0    1.0      1.0       Unit
# 3   West Ryde NSW 2114   2.0    1.0      1.0       Unit
# 4  Canterbury NSW 2193   2.0    2.0      2.0       Unit
#
#                               Sale Type              Price
# 0       Sold by Auction  on 02 Nov 2021         $1,950,000
# 1  Sold by Private Sale  on 01 Nov 2021           $960,000
# 2  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 3  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 4  Sold by Private Sale  on 01 Nov 2021           $740,000

# %%
# Fill null values in column: "Type". If there's a slash(/) in the address, it's an apartment, else it's a house.

nulls = rma1[rma1['Type'].isnull()]
apartments = nulls[nulls.Address.str.contains('/')]
houses = nulls[~nulls.Address.str.contains('/')]
for i in houses.index:
    rma1.at[i,'Type'] = 'House'
for i in apartments.index:
    rma1.at[i,'Type'] = 'Apartment'

# %%
# Fill null values in column: "Carpark". If it's an apartment, there's no parking. If it's a house, there's 2 parking spaces.

nulls = rma1[rma1['Carpark'].isnull()]
apartments = nulls[nulls.Address.str.contains('/')]
houses = nulls[~nulls.Address.str.contains('/')]
for i in houses.index:
    rma1.at[i,'Carpark'] = 1
for i in apartments.index:
    rma1.at[i,'Carpark'] = 0

# %%
rma1.isnull().sum()
# Out:
# Link         73
# Address       0
# Suburb        0
# Beds          0
# Baths        33
# Carpark       0
# Type          0
# Sale Type     8
# Price         0
# dtype: int64

# %%
rma1.head()
# Out:
#                                                 Link              Address  \
# 0  https://www.ratemyagent.com.au/real-estate-age...  7A Australia Street
# 1  https://www.ratemyagent.com.au/real-estate-age...      9/46 Stewart St
# 2  https://www.ratemyagent.com.au/real-estate-age...    39 William Street
# 3  https://www.ratemyagent.com.au/real-estate-age...    7/12 Union Street
# 4  https://www.ratemyagent.com.au/real-estate-age...  404/2A Cooks Avenue
#
#                 Suburb  Beds  Baths  Carpark       Type  \
# 0  Camperdown NSW 2050   2.0    2.0      1.0  Townhouse
# 1   Ermington NSW 2115   3.0    2.0      1.0  Townhouse
# 2   Granville NSW 2142   1.0    1.0      1.0       Unit
# 3   West Ryde NSW 2114   2.0    1.0      1.0       Unit
# 4  Canterbury NSW 2193   2.0    2.0      2.0       Unit
#
#                               Sale Type              Price
# 0       Sold by Auction  on 02 Nov 2021         $1,950,000
# 1  Sold by Private Sale  on 01 Nov 2021           $960,000
# 2  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 3  Sold by Private Sale  on 01 Nov 2021  Price unavailable
# 4  Sold by Private Sale  on 01 Nov 2021           $740,000

# %%
# Split sale type and date

rma1['Sale Type'] = rma['Sale Type'].str.replace('Sold by ','' )

# %%
saletype = rma1['Sale Type'].str.split(' on ',expand=True)
for i in saletype.columns:
    rma1[i] = saletype[i]

# %%
rma2 = rma1.drop('Sale Type',axis=1)
rma2.rename({0:'By',1:'Date'},axis=1,inplace=True)

# trim price
rma2['Price'] = rma2['Price'].str.replace('$','').str.replace(',','')

# to datetime just in case
rma2['Date']=pd.to_datetime(rma2['Date'])

# %%
sales_rma = rma2.copy()
sales_rma
# Out:
#                                                     Link  \
# 0      https://www.ratemyagent.com.au/real-estate-age...
# 1      https://www.ratemyagent.com.au/real-estate-age...
# 2      https://www.ratemyagent.com.au/real-estate-age...
# 3      https://www.ratemyagent.com.au/real-estate-age...
# 4      https://www.ratemyagent.com.au/real-estate-age...
# ...                                                  ...
# 28400  https://www.ratemyagent.com.au/real-estate-age...
# 28401  https://www.ratemyagent.com.au/real-estate-age...
# 28402  https://www.ratemyagent.com.au/real-estate-age...
# 28403  https://www.ratemyagent.com.au/real-estate-age...
# 28404  https://www.ratemyagent.com.au/real-estate-age...
#
#                      Address                   Suburb  Beds  Baths  Carpark  \
# 0        7A Australia Street      Camperdown NSW 2050   2.0    2.0      1.0
# 1            9/46 Stewart St       Ermington NSW 2115   3.0    2.0      1.0
# 2          39 William Street       Granville NSW 2142   1.0    1.0      1.0
# 3          7/12 Union Street       West Ryde NSW 2114   2.0    1.0      1.0
# 4        404/2A Cooks Avenue      Canterbury NSW 2193   2.0    2.0      2.0
# ...                      ...                      ...   ...    ...      ...
# 28400    301/7 Sevier Avenue          Rhodes NSW 2138   2.0    2.0      1.0
# 28401    36/132 Killeaton St         St Ives NSW 2075   2.0    2.0      1.0
# 28402        12/19 Selwyn St  Wollstonecraft NSW 2065   2.0    1.0      1.0
# 28403  5/62 Middle Head Road          Mosman NSW 2088   2.0    1.0      1.0
# 28404     9/33 Church Street      Birchgrove NSW 2041   2.0    1.0      1.0
#
#             Type              Price             By       Date
# 0      Townhouse            1950000       Auction  2021-11-02
# 1      Townhouse             960000  Private Sale  2021-11-01
# 2           Unit  Price unavailable  Private Sale  2021-11-01
# 3           Unit  Price unavailable  Private Sale  2021-11-01
# 4           Unit             740000  Private Sale  2021-11-01
# ...          ...                ...            ...        ...
# 28400  Apartment  Price unavailable       Auction  2021-05-29
# 28401  Apartment             935000       Auction  2021-05-29
# 28402  Apartment  Price unavailable       Auction  2021-05-29
# 28403  Apartment  Price unavailable       Auction  2021-05-29
# 28404  Apartment            1155000       Auction  2021-05-29
#
# [28315 rows x 10 columns]

# %% [markdown]
# ## Prepare datasets before joining
#
# Unify Street Names (Street -> St, etc.)

# %%
sales_gov.Address = sales_gov.Address.str.title().str.strip()
sales_gov.Suburb = sales_gov.Suburb.str.title().str.strip()
sales_rma.Address = sales_rma.Address.str.title().str.strip()
sales_rma.Suburb = sales_rma.Suburb.str.title().str.strip()

# %%
road_names = sales_rma.Address.str.split(' ', expand = True)

# %%
rd_names = road_names[2].unique()

filtered = []
for n in rd_names:
    if n == None:
        pass
    elif len(n)<3:
            filtered.append(n)

filtered
# Out:
# ['St',
#  'Rd',
#  'Pl',
#  'Cl',
#  'Ln',
#  'Dr',
#  'Sp',
#  'La',
#  '16',
#  'Ct',
#  'N',
#  'On',
#  '&',
#  'De',
#  'Av',
#  'Of',
#  'Vw']

# %%
road_names[road_names[2]=='Cl']
# Out:
#            0        1   2     3     4     5     6     7     8
# 237        6  Goodlet  Cl  None  None  None  None  None  None
# 599        2  William  Cl  None  None  None  None  None  None
# 1308       7  Roberts  Cl  None  None  None  None  None  None
# 1508    12/3  Packard  Cl  None  None  None  None  None  None
# 2317    39/3     Ramu  Cl  None  None  None  None  None  None
# ...      ...      ...  ..   ...   ...   ...   ...   ...   ...
# 23765   37/2   Belair  Cl  None  None  None  None  None  None
# 25893   11/6  Fairway  Cl  None  None  None  None  None  None
# 26523   23/5   Belair  Cl  None  None  None  None  None  None
# 27429  124/2  Dolphin  Cl  None  None  None  None  None  None
# 27956   18/1   Belair  Cl  None  None  None  None  None  None
#
# [61 rows x 9 columns]

# %%
rma2.loc[237]
# Out:
# Link       https://www.ratemyagent.com.au/real-estate-age...
# Address                                         6 Goodlet Cl
# Suburb                              Lane Cove North NSW 2066
# Beds                                                     3.0
# Baths                                                    2.0
# Carpark                                                  2.0
# Type                                               Townhouse
# Price                                      Price unavailable
# By                                             Private Sale
# Date                                     2021-10-21 00:00:00
# Name: 237, dtype: object

# %%
abbr = [
    [' Street',' St'],
    [' Road',' Rd'],
    [' Avenue',' Ave'],
    [' Place',' Pl'],
    [' Close',' Cl'],
    [' Lane',' Ln'],
    [' Drive',' Dr'],
    [' Highway',' Hwy'],
    [' Parade',' Pde'],
    [' Square',' Sq'],
    [' Court',' Ct'],
    [' Glade',' Gld'],

    ['Parkway','Pkwy'],
    ['Boulevard','Blvd'],
    ['Circuit','Cct'],
    
    [' st',' St'],
    [' st.',' St'],
    [' ST',' St'],
    [' RD',' Rd'],
    [' ave', 'Ave'],
    [' AVE', 'Ave'],
    [' road',' Rd'],
    [' ROAD',' Rd'],
    ['Crt','Ct'],
    ['Pde.','Pde'],

    [' Crescent',' Cres'],
    [' Glen',' Gln'],
    [' Plaza', 'Plz'],
    [' View', ' Vw'],

    ['Mallard La', 'Mallard Ln']
]

# %%
# replace all street address names with abbreviation
for row in abbr:
    sales_gov.Address = sales_gov.Address.str.replace(row[0],row[1])
    sales_rma.Address = sales_rma.Address.str.replace(row[0],row[1])

# %%
sales_gov.sample(5)
# Out:
#                  Address                   Suburb    Price   Size        Date
# 870411  21/46 Cobbett St  Wetherill Park Nsw 2164   680000    0.0  2018-06-19
# 887162        8 Ibis Pde       Woodberry Nsw 2322   270000  461.6  2020-03-06
# 592437     13 Nunkeri Pl     North Nowra Nsw 2541   471000  719.4  2018-10-16
# 813223  15/60 Manning St        Tuncurry Nsw 2428   214500    0.0  2020-03-06
# 93500    71 Mill Hill Rd  Bondi Junction Nsw 2022  1800000  196.0  2020-07-23

# %% [markdown]
# Unifying Suburb Names:

# %%
rma_suburbs = pd.DataFrame(sales_rma.Suburb.unique())
rma_suburbs.columns = ['Name']

# %%
gov_suburbs = pd.DataFrame(sales_gov.Suburb.unique())
gov_suburbs.columns = ['Name']

# %%
rma_suburbs.Name.isin(gov_suburbs.Name).astype(int).unique()
# Out:
# array([1])

# %% [markdown]
# Seems every suburb is included in the NSW dataset, which means there's no error in the Naming

# %% [markdown]
# ## Join Two Datasets

# %%
sales = pd.merge(sales_rma,sales_gov, on=['Address','Suburb'])
sales.shape
# Out:
# (21403, 13)

# %%
sales
# Out:
#                                                     Link              Address  \
# 0      https://www.ratemyagent.com.au/real-estate-age...      9/46 Stewart St
# 1      https://www.ratemyagent.com.au/real-estate-age...      13/28A Henry St
# 2      https://www.ratemyagent.com.au/real-estate-age...      4/29 Norfolk St
# 3      https://www.ratemyagent.com.au/real-estate-age...      4/5 Thurston St
# 4      https://www.ratemyagent.com.au/real-estate-age...    2/43 Mackenzie St
# ...                                                  ...                  ...
# 21398  https://www.ratemyagent.com.au/real-estate-age...  36/132 Killeaton St
# 21399  https://www.ratemyagent.com.au/real-estate-age...      12/19 Selwyn St
# 21400  https://www.ratemyagent.com.au/real-estate-age...      12/19 Selwyn St
# 21401  https://www.ratemyagent.com.au/real-estate-age...  5/62 Middle Head Rd
# 21402  https://www.ratemyagent.com.au/real-estate-age...       9/33 Church St
#
#                         Suburb  Beds  Baths  Carpark       Type  \
# 0           Ermington Nsw 2115   3.0    2.0      1.0  Townhouse
# 1            Ashfield Nsw 2131   2.0    1.0      1.0       Unit
# 2           Blacktown Nsw 2148   2.0    2.0      1.0  Townhouse
# 3             Penrith Nsw 2750   2.0    1.0      1.0       Unit
# 4         Strathfield Nsw 2135   3.0    2.0      2.0  Townhouse
# ...                        ...   ...    ...      ...        ...
# 21398         St Ives Nsw 2075   2.0    2.0      1.0  Apartment
# 21399  Wollstonecraft Nsw 2065   2.0    1.0      1.0  Apartment
# 21400  Wollstonecraft Nsw 2065   2.0    1.0      1.0  Apartment
# 21401          Mosman Nsw 2088   2.0    1.0      1.0  Apartment
# 21402      Birchgrove Nsw 2041   2.0    1.0      1.0  Apartment
#
#                  Price_x             By     Date_x  Price_y  Size      Date_y
# 0                 960000  Private Sale  2021-11-01   960000   0.0  2021-09-18
# 1                 650000       Auction  2021-11-01   520000   0.0  2019-11-02
# 2                 670000  Private Sale  2021-11-01   630000   0.0  2018-06-15
# 3      Price unavailable  Private Sale  2021-11-01   376000   0.0  2017-07-15
# 4                1677000       Auction  2021-11-01  1475000   0.0  2019-05-30
# ...                  ...            ...        ...      ...   ...         ...
# 21398             935000       Auction  2021-05-29   935000   0.0  2021-05-29
# 21399  Price unavailable       Auction  2021-05-29  1500000   0.0  2021-05-29
# 21400  Price unavailable       Auction  2021-05-29  1180000   0.0  2017-10-14
# 21401  Price unavailable       Auction  2021-05-29  1130000   0.0  2021-05-29
# 21402            1155000       Auction  2021-05-29  1155000   0.0  2021-05-29
#
# [21403 rows x 13 columns]

# %%
# sort by time
sales1=sales.copy()
sales1['Date_y'] = pd.to_datetime(sales['Date_y'])
sales1['Date_x'] = pd.to_datetime(sales['Date_x'])

sales1.sort_values(by='Date_y', ascending=False , inplace=True)
# sales1.set_index(keys='Date_y', drop=True, inplace=True)

# %%
sales1.sample(10)
# Out:
#                                                     Link              Address  \
# 8197   https://www.ratemyagent.com.au/real-estate-age...        160 Coward St
# 19879  https://www.ratemyagent.com.au/real-estate-age...       807/10 Avon Rd
# 2134   https://www.ratemyagent.com.au/real-estate-age...       3/66 Buller St
# 17741  https://www.ratemyagent.com.au/real-estate-age...       22/40 Park Ave
# 19855  https://www.ratemyagent.com.au/real-estate-age...  310/21 Grosvenor St
# 16630  https://www.ratemyagent.com.au/real-estate-age...     4/30 Wheeler Pde
# 16188  https://www.ratemyagent.com.au/real-estate-age...      5C/8 Hampden St
# 20007  https://www.ratemyagent.com.au/real-estate-age...   3/4 Rothschild Ave
# 18041  https://www.ratemyagent.com.au/real-estate-age...       4/29A Innes Rd
# 18345  https://www.ratemyagent.com.au/real-estate-age...   119/149 Pyrmont St
#
#                           Suburb  Beds  Baths  Carpark       Type  \
# 8197             Mascot Nsw 2020   3.0    1.0      3.0      House
# 19879            Pymble Nsw 2073   2.0    1.0      1.0  Apartment
# 2134   North Parramatta Nsw 2151   3.0    2.0      2.0  Townhouse
# 17741           Waitara Nsw 2077   1.0    1.0      1.0  Apartment
# 19855       Neutral Bay Nsw 2089   1.0    1.0      0.0  Apartment
# 16630           Dee Why Nsw 2099   2.0    2.0      2.0  Apartment
# 16188        Paddington Nsw 2021   1.0    1.0      1.0  Apartment
# 20007          Rosebery Nsw 2018   1.0    1.0      1.0  Apartment
# 18041         Greenwich Nsw 2065   2.0    1.0      1.0  Apartment
# 18345           Pyrmont Nsw 2009   2.0    2.0      1.0  Apartment
#
#                  Price_x             By     Date_x  Price_y   Size     Date_y
# 8197             2095000       Auction  2021-10-02  2095000  550.1 2021-10-01
# 19879  Price unavailable  Private Sale  2021-06-25   825000    0.0 2021-06-25
# 2134              840000  Private Sale  2021-07-03   770000    0.0 2020-01-15
# 17741             520000  Private Sale  2021-08-05   520000    0.0 2021-07-26
# 19855  Price unavailable  Private Sale  2021-06-25   750000    0.0 2021-06-25
# 16630            1515000  Private Sale  2021-08-27  1515000    0.0 2021-08-26
# 16188  Price unavailable       Auction  2021-09-04   761000    0.0 2021-09-04
# 20007  Price unavailable  Private Sale  2021-06-23   832000    0.0 2021-06-23
# 18041             825000  Private Sale  2021-07-28   825000    0.0 2021-07-28
# 18345            1022000  Private Sale  2021-07-23  1022000    0.0 2021-07-22

# %%
cols = ['Address','Suburb','Beds','Baths','Carpark','Type','Size','By','Price_x','Price_y', 'Date_x','Date_y']
sales2 = sales1[cols]

# %%
sales2.rename({'Price_x':'Price_rma','Price_y':'Price_gov','Date_x':'Date_rma','Date_y':'Date_gov'},axis=1,inplace=True)
sales2.shape
# Out:
# (21403, 12)

# %%
sales2 = sales2.drop_duplicates(subset=['Address','Suburb','Price_gov'],keep='last')

# %%
sales2.head(10)
# Out:
#                  Address                   Suburb  Beds  Baths  Carpark  \
# 9423           5 Ryan St       Lilyfield Nsw 2040   5.0    3.0      1.0
# 11131  38 Nightingale Sq       Glossodia Nsw 2756   3.0    1.0      2.0
# 7566        20 Gatley Ct    Wattle Grove Nsw 2173   4.0    2.0      1.0
# 15210    2/17 Isabel Ave        Vaucluse Nsw 2030   3.0    2.0      2.0
# 9036        20 Prince St  Canley Heights Nsw 2166   3.0    1.0      1.0
# 8468    81 Coogee Bay Rd        Randwick Nsw 2031   3.0    2.0      1.0
# 13966    913/187 Kent St   Millers Point Nsw 2000   1.0    1.0      0.0
# 13085     629 Polding St    Bossley Park Nsw 2176   3.0    1.0      1.0
# 310      24/75 Broome St        Maroubra Nsw 2035   1.0    1.0      1.0
# 7092   7A South Creek Rd         Dee Why Nsw 2099   3.0    1.0      2.0
#
#             Type   Size             By          Price_rma  Price_gov  \
# 9423       House  219.7       Auction             2830000    2830000
# 11131      House  980.1  Private Sale              880000     880000
# 7566       House  483.0  Private Sale             1130000    1130000
# 15210  Apartment    0.0       Auction   Price unavailable    3462000
# 9036       House  442.6  Private Sale              850000     850000
# 8468       House  297.2       Auction   Price unavailable    3080000
# 13966  Apartment    0.0  Private Sale             1100000    1100000
# 13085      House  564.6       Auction              940000     940000
# 310         Unit    0.0  Private Sale              720000     720000
# 7092       House  323.7  Private Sale   Price unavailable    1890000
#
#         Date_rma   Date_gov
# 9423  2021-09-18 2021-11-17
# 11131 2021-08-31 2021-11-17
# 7566  2021-10-14 2021-11-16
# 15210 2021-09-23 2021-11-10
# 9036  2021-09-22 2021-11-08
# 8468  2021-09-29 2021-11-05
# 13966 2021-11-01 2021-11-01
# 13085 2021-08-10 2021-10-28
# 310   2021-10-07 2021-10-27
# 7092  2021-10-26 2021-10-26

# %% [markdown]
# ## Showing the differences between the two datasets

# %%
sales_rma[(sales_rma['Suburb']=='West Ryde Nsw 2114')].sort_values('Date',ascending=False)[0:10].drop(['Link','Type','By','Beds','Baths','Carpark'],axis=1)
# Out:
#                  Address              Suburb              Price       Date
# 3          7/12 Union St  West Ryde Nsw 2114  Price unavailable 2021-11-01
# 8672      23 Falconer St  West Ryde Nsw 2114            2580000 2021-10-30
# 9425       23 Reserve St  West Ryde Nsw 2114            2461000 2021-10-23
# 19217  7/15 Riverview St  West Ryde Nsw 2114             475000 2021-10-20
# 19588   17/20 Herbert St  West Ryde Nsw 2114  Price unavailable 2021-10-14
# 10770    54 Hermitage Rd  West Ryde Nsw 2114  Price unavailable 2021-10-13
# 10741         14 Moss St  West Ryde Nsw 2114            2270000 2021-10-13
# 19810     67/57 West Pde  West Ryde Nsw 2114             482000 2021-10-12
# 10935     15 Falconer St  West Ryde Nsw 2114            2880000 2021-10-12
# 689       2B Hermoyne St  West Ryde Nsw 2114            1560000 2021-10-06

# %%
sales_gov[(sales_gov['Suburb']=='West Ryde Nsw 2114')].sort_values('Date',ascending=False)[0:10].drop(['Size'],axis=1)
# Out:
#                    Address              Suburb    Price        Date
# 865010   7/15 Riverview St  West Ryde Nsw 2114   475000  2021-10-08
# 865108        6/4 Union St  West Ryde Nsw 2114   580000  2021-10-05
# 864860  7/1A Macpherson St  West Ryde Nsw 2114  1400000  2021-10-02
# 865289    32/22 Herbert St  West Ryde Nsw 2114   760000  2021-10-01
# 864503    4/12 Adelaide St  West Ryde Nsw 2114    12200  2021-09-24
# 865058     4/84 Station St  West Ryde Nsw 2114   655000  2021-09-22
# 865203      67/61 West Pde  West Ryde Nsw 2114   482000  2021-09-21
# 864837       12 Lambert St  West Ryde Nsw 2114  1840000  2021-09-18
# 864685    9/2 Mulvihill St  West Ryde Nsw 2114   285000  2021-09-16
# 865204      30/61 West Pde  West Ryde Nsw 2114   660000  2021-09-15

# %%
sales2[sales2['Suburb']=='West Ryde Nsw 2114'].sort_values('Date_rma',ascending=False)[0:5]
# Out:
#                  Address              Suburb  Beds  Baths  Carpark       Type  \
# 7134       23 Reserve St  West Ryde Nsw 2114   5.0    4.0      2.0      House
# 14159  7/15 Riverview St  West Ryde Nsw 2114   1.0    1.0      1.0  Apartment
# 386      4/84 Station St  West Ryde Nsw 2114   2.0    1.0      1.0       Unit
# 15035     30/61 West Pde  West Ryde Nsw 2114   2.0    1.0      1.0  Apartment
# 9381       12 Lambert St  West Ryde Nsw 2114   3.0    1.0      2.0      House
#
#         Size             By Price_rma  Price_gov   Date_rma   Date_gov
# 7134   809.4       Auction    2461000    2060000 2021-10-23 2017-12-09
# 14159    0.0  Private Sale     475000     475000 2021-10-20 2021-10-08
# 386      0.0  Private Sale     655000     655000 2021-10-01 2021-09-22
# 15035    0.0  Private Sale     660000     660000 2021-09-27 2021-09-15
# 9381   742.6       Auction    1840000    1840000 2021-09-18 2021-09-18

# %% [markdown]
# 1. RMA dataset is newer, Gov dataset ends 24 Oct, 2021.
# 2. Although RMA's records are newer, sometimes the date stamp comes later than the Gov records.
# 3. RMA dataset contains some of the sales that's not been submitted to the government. E.g., some of the sales from Sept 2021 are still not in the Gov dataset.
# 4. RMA dataset is not complete, some of the sales that's in the Gov dataset is not in the RMA dataset. Those properties were probably sold privately or were sold on other platforms.

# %%
# This cell exists solely because someone may want to remove the flipped houses (sold again within a few months),
# uncomment the next line if you want one property to have only one sale record, which has the most recent sale record.

# sales3 = sales2.drop_duplicates(subset=['Address','Suburb'],keep='first') 
sales3 = sales2.copy()
sales3.shape
# Out:
# (20937, 12)

# %% [markdown]
# ## Fill "Price unavailable" from government dataset
#
# The rma data set contains the latest sale prices, but some the prices are listed as "unavailable", either because they are sold else where or because the price was never disclosed by the seller or buyer.
#
# Lucky for us, these transactions have to be disclosed to the government within a few months of selling. So, we can get the missing prices from the government dataset.

# %% [markdown]
# ** "Last Known Price" Disclaimer
#
# For most of the time, the government dataset lags behind the real time sales, because people need time to settle the deal, sometimes by several months. This is why we can eventually get all of the price data from the government. But for the recent months, we will have to make do with the data from RMA.
#
# One problem caused by filling the price from the government dataset is: if a property was sold again within a few months, the price we fill from the government will be the last known prices, but not the most recent ones.
#
# E.g., 3 month ago, a house was sold by private sale for 1.0 million. Since it's "private", rma didn't get the price (sometimes they do although this time they didn't), so the price of this sale was marked as "unavailable". Then the transaction went through in a few days, and the government got the settled price: "1.0 million" and recorded it. Fast forward to today, the house was sold again for 1.5 million, RMA still didn't get the price(maybe another private sale), so this time it was still marked as "price unavailable". If at this stage we get the data from both rma and government, and fill the price recorded by the government of 1.0 million to this sale, then apparently it's wrong.
#
# In short, this means the data can be misleading, and the house price may not be the actual price, but the "last known price". Fortunately if we update the government dataset constantly in the following months, we will eventually get the accurate prices for recent sales, but of course, the data won't be as fresh by then.

# %%
print('There are',sales3[sales3.Price_rma == 'Price unavailable'].shape[0],'records without price.')
sales3[sales3.Price_rma == 'Price unavailable'][0:10]
# Out:
# There are 6330 records without price.
#                   Address                    Suburb  Beds  Baths  Carpark  \
# 15210     2/17 Isabel Ave         Vaucluse Nsw 2030   3.0    2.0      2.0
# 8468     81 Coogee Bay Rd         Randwick Nsw 2031   3.0    2.0      1.0
# 7092    7A South Creek Rd          Dee Why Nsw 2099   3.0    1.0      2.0
# 7133       97 Hargrave St       Paddington Nsw 2021   3.0    1.0      1.0
# 7148        6 Coolaroo Rd  Lane Cove North Nsw 2066   3.0    1.0      3.0
# 14107    6/217 Malabar Rd     South Coogee Nsw 2034   3.0    1.0      1.0
# 14086  202/127 Pennant St       Parramatta Nsw 2150   2.0    2.0      1.0
# 14138    10/31 Addison Rd            Manly Nsw 2095   3.0    2.0      2.0
# 7221         5 Glnview Cl      Bella Vista Nsw 2153   5.0    3.0      3.0
# 15318       2/66 Helen St  Lane Cove North Nsw 2066   2.0    1.0      1.0
#
#             Type    Size             By          Price_rma  Price_gov  \
# 15210  Apartment    0.00       Auction   Price unavailable    3462000
# 8468       House  297.20       Auction   Price unavailable    3080000
# 7092       House  323.70  Private Sale   Price unavailable    1890000
# 7133       House   94.84       Auction   Price unavailable    2755000
# 7148       House  562.80       Auction   Price unavailable    3450000
# 14107  Apartment    0.00  Private Sale   Price unavailable    1485000
# 14086  Apartment    0.00  Private Sale   Price unavailable     645000
# 14138  Apartment    0.00       Auction   Price unavailable    3100000
# 7221       House  660.10       Auction   Price unavailable    2950000
# 15318  Apartment    0.00       Auction   Price unavailable     950000
#
#         Date_rma   Date_gov
# 15210 2021-09-23 2021-11-10
# 8468  2021-09-29 2021-11-05
# 7092  2021-10-26 2021-10-26
# 7133  2021-10-23 2021-10-23
# 7148  2021-10-23 2021-10-23
# 14107 2021-10-22 2021-10-22
# 14086 2021-10-22 2021-10-22
# 14138 2021-10-21 2021-10-21
# 7221  2021-10-21 2021-10-21
# 15318 2021-09-21 2021-10-21

# %%
# from dateutil.relativedelta import *

for i in sales3.index:
    entry = sales3.loc[i]
    if entry.Price_rma == 'Price unavailable':
        date_rma = entry.Date_rma
        date_gov = entry.Date_gov

        # date_1mon_before = date_gov + relativedelta(months=-2)
        # date_1mon_after = date_gov + relativedelta(months=+2)

        if date_rma<date_gov:
            sales3.at[i, 'Price_rma']=sales3.loc[i].Price_gov

# %%
# Removing the entries with no Price

sales4 = sales3[sales3.Price_rma!="Price unavailable"]

# %% [markdown]
# # Clean up

# %%
sales4.isnull().sum()[sales4.isnull().sum()!=0]
# Out:
# Baths       9
# Size        2
# By          1
# Date_rma    1
# dtype: int64

# %%
# check for null values in time columns
sales4[sales4.Date_rma.isnull() | sales4.Date_gov.isnull()]
# Out:
#                  Address               Suburb  Beds  Baths  Carpark  \
# 19728  1502/3 Network Pl  North Ryde Nsw 2113   1.0    1.0      1.0
#
#             Type  Size   By Price_rma  Price_gov Date_rma   Date_gov
# 19728  Apartment   0.0  NaN    705000     705000      NaT 2021-06-21

# %%
for i in range(0, len(sales4)):
    if pd.isnull(sales4['Date_rma'].iloc[i]):
        sales4['Date_rma'].iloc[i] = sales4['Date_gov'].iloc[i]

# %%
# properties without baths
sales4[sales4.Baths.isnull()]
# Out:
#                    Address                 Suburb  Beds  Baths  Carpark  \
# 14707   70/95 Annandale St     Annandale Nsw 2038   1.0    NaN      0.0
# 9216     102 Broomfield St    Cabramatta Nsw 2166   1.0    NaN      1.0
# 16962        28/1 Dwyer St   Chippendale Nsw 2008   1.0    NaN      0.0
# 12528        63 Amarco Cct     The Ponds Nsw 2769   2.0    NaN      1.0
# 17791       38/5 Darley St  Darlinghurst Nsw 2010   1.0    NaN      0.0
# 18816  109/72 Henrietta St      Waverley Nsw 2024   1.0    NaN      0.0
# 18091       618/18 Park Ln   Chippendale Nsw 2008   1.0    NaN      0.0
# 19106     1/80 Victoria Rd  Marrickville Nsw 2204   1.0    NaN      0.0
# 20093      402/355 Kent St        Sydney Nsw 2000   1.0    NaN      0.0
#
#             Type   Size             By Price_rma  Price_gov   Date_rma  \
# 14707  Apartment    0.0  Private Sale     300000     300000 2021-10-04
# 9216       House  885.2       Auction    2150000    2150000 2021-09-20
# 16962  Apartment    0.0  Private Sale     370000     370000 2021-08-20
# 12528      House  600.3  Private Sale    1530000    1530000 2021-08-16
# 17791  Apartment    0.0       Auction     485000     485000 2021-08-03
# 18816  Apartment    0.0       Auction     500000     500000 2021-07-14
# 18091  Apartment    0.0  Private Sale     575000     575000 2021-07-27
# 19106  Apartment    0.0       Auction     505000     505000 2021-07-08
# 20093  Apartment    0.0  Private Sale     660000     660000 2021-06-22
#
#         Date_gov
# 14707 2021-10-04
# 9216  2021-09-22
# 16962 2021-08-20
# 12528 2021-08-16
# 17791 2021-08-03
# 18816 2021-07-14
# 18091 2021-07-13
# 19106 2021-07-08
# 20093 2021-06-15

# %%
# after checking some of the apartment listed here on other platforms such as domain.com.au,
# I found that most of these 1 bed apartments have at lease 1 bathroom, so they are filled with 1.

sales4.loc[(sales4.Baths.isnull()) & (sales4.Type == 'Apartment'), 'Baths'] = 1

# %%
sales4[sales4.Baths.isnull()]
# Out:
#                  Address               Suburb  Beds  Baths  Carpark   Type  \
# 9216   102 Broomfield St  Cabramatta Nsw 2166   1.0    NaN      1.0  House
# 12528      63 Amarco Cct   The Ponds Nsw 2769   2.0    NaN      1.0  House
#
#         Size             By Price_rma  Price_gov   Date_rma   Date_gov
# 9216   885.2       Auction    2150000    2150000 2021-09-20 2021-09-22
# 12528  600.3  Private Sale    1530000    1530000 2021-08-16 2021-08-16

# %%
# these two etries are wrong after checking, so I simply dropped them. RMA's employees didn't do their job on this two rows.
sales5 = sales4.drop([9216, 12528], axis=0)

# %%
sales5[sales5.isnull().any(axis=1)]
# Out:
#                  Address                 Suburb  Beds  Baths  Carpark  \
# 11123      27B Alfred Rd  Forest Lodge Nsw 2037   2.0    2.0      2.0
# 12613       5 Burnell St     Drummoyne Nsw 2047   4.0    2.0      4.0
# 19728  1502/3 Network Pl    North Ryde Nsw 2113   1.0    1.0      1.0
#
#             Type  Size        By Price_rma  Price_gov   Date_rma   Date_gov
# 11123      House   NaN  Auction    2085000    2085000 2021-08-31 2021-08-31
# 12613      House   NaN  Auction    7575000    7575000 2021-08-14 2021-08-14
# 19728  Apartment   0.0       NaN    705000     705000 2021-06-21 2021-06-21

# %%
sales5.loc[sales5.By.isnull() , 'By'] = 'Auction' # Let it be auction, doesn't matter
sales5.loc[11123, 'Size'] = 160
sales5.loc[12613, 'Size'] = 695

# %%
if sales5.isnull().sum().sum()==0:
    print("No null values")
else:
    print(sales5.isnull().sum()[sales5.isnull().sum()!=0])
# Out:
# No null values

# %% [markdown]
# ## Final Trim

# %%
recent_sales=sales5.drop(columns=['Price_gov','Date_gov']) # we will use the more recent price column, which was rma's with prices filled from gov's
recent_sales.rename({'Price_rma':'Price','Date_rma':'Date'},axis=1,inplace=True) # we will use only one time column, doesn't matter if it's rma's or gov's
recent_sales.sort_values('Date',ascending=False,inplace=True)

#export to csv
recent_sales.to_csv( "./data/recent_sales.csv", index=False, encoding='utf-8-sig')

# %%
recent_sales
# Out:
#                  Address                   Suburb  Beds  Baths  Carpark  \
# 1        13/28A Henry St        Ashfield Nsw 2131   2.0    1.0      1.0
# 6960         4 Yvette St  Baulkham Hills Nsw 2153   4.0    2.0      1.0
# 6958       9 Nichols Ave         Revesby Nsw 2212   3.0    1.0      1.0
# 6956     52 Charlotte Rd      Rooty Hill Nsw 2766   3.0    2.0      3.0
# 6954    10 Lillypilly St         Colebee Nsw 2761   5.0    3.0      2.0
# ...                  ...                      ...   ...    ...      ...
# 6941   2/402 Railway Pde         Allawah Nsw 2218   2.0    1.0      2.0
# 6937      5/22 Ramona St    Quakers Hill Nsw 2763   4.0    2.0      2.0
# 6935    10/10 Marsden Rd        St Marys Nsw 2760   3.0    2.0      2.0
# 6944   3/240 Katoomba St        Katoomba Nsw 2780   3.0    1.0      1.0
# 6947  68/107 Pacific Hwy         Hornsby Nsw 2077   3.0    2.0      2.0
#
#            Type    Size             By    Price       Date
# 1          Unit    0.00       Auction    650000 2021-11-01
# 6960      House  695.60  Private Sale   1625000 2021-11-01
# 6958      House  557.34       Auction   1350000 2021-11-01
# 6956      House  550.20  Private Sale    895000 2021-11-01
# 6954      House  533.40  Private Sale   1437000 2021-11-01
# ...         ...     ...            ...      ...        ...
# 6941       Unit    0.00  Private Sale    620000 2020-11-03
# 6937  Townhouse    0.00  Private Sale    750000 2020-11-03
# 6935  Townhouse    0.00  Private Sale    497500 2020-11-03
# 6944  Townhouse    0.00  Private Sale    565000 2020-11-03
# 6947       Unit    0.00  Private Sale    965000 2020-11-03
#
# [14771 rows x 10 columns]

# %%
# %store recent_sales
# Out:
# Stored 'recent_sales' (DataFrame)
